# %% [markdown]
# <a href="https://colab.research.google.com/github/jose4747/Data-science-1/blob/main/Heart_Disease_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path='/content/drive/MyDrive/Colab Notebooks/heart.data.csv'
import pandas as pd
df = pd.read_csv(path)
df
# Out:
#      Unnamed: 0     biking    smoking  heart.disease
# 0             1  30.801246  10.896608      11.769423
# 1             2  65.129215   2.219563       2.854081
# 2             3   1.959665  17.588331      17.177803
# 3             4  44.800196   2.802559       6.816647
# 4             5  69.428454  15.974505       4.062224
# ..          ...        ...        ...            ...
# 493         494  47.660440  27.562464      11.294392
# 494         495  45.097203  21.385620       9.616762
# 495         496   8.279743   6.423720      13.495168
# 496         497  42.345863  20.741328      10.115865
# 497         498  30.774254  23.610175      11.843556
#
# [498 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
x = df['smoking']
y = df['heart.disease']
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.75, shuffle = True)
from sklearn.linear_model import LinearRegression
print(x_train.shape)
print(x_test.shape)
# Out:
# (373,)
# (125,)

# %%
import numpy as np
x_train=np.array(x_train).reshape(-1,1)
y_train=np.array(y_train).reshape(-1,1)

model=LinearRegression()
model. fit(x_train,y_train)

print (model. coef_)
print(model.intercept_)
# Out:
# [[0.12240279]]
# [8.12514388]

# %%
y_test=np.array(y_test).reshape(-1,1)
y_pred=model.predict(y_test)
print(y_pred)
# Out:
# [[ 8.95896918]
#  [ 9.07955511]
#  [ 9.7952513 ]
#  [ 9.79902428]
#  [ 9.69172658]
#  [ 8.27577016]
#  [ 9.04800434]
#  [ 9.37153302]
#  [ 9.19853711]
#  [ 9.5619661 ]
#  [ 9.43170161]
#  [ 9.04461735]
#  [ 9.88041857]
#  [ 9.05496139]
#  [ 8.19435958]
#  [ 8.48267852]
#  [ 8.33079823]
#  [ 8.57295598]
#  [ 8.89860026]
#  [ 9.00964359]
#  [ 9.86662278]
#  [10.13919904]
#  [10.46168778]
#  [ 8.35036349]
#  [ 8.69564753]
#  [ 8.46467205]
#  [ 9.50785724]
#  [10.33269843]
#  [ 8.63626248]
#  [ 8.528898  ]
#  [10.10429107]
#  [10.45915426]
#  [ 8.0653218 ]
#  [10.04901912]
#  [ 8.62081821]
#  [ 9.35248804]
#  [ 9.08029611]
#  [ 9.21292531]
#  [ 9.58011029]
#  [ 8.68507221]
#  [ 7.73362769]
#  [10.12640282]
#  [ 8.62415752]
#  [ 9.34812504]
#  [ 8.64181251]
#  [ 9.65246409]
#  [10.45391915]
#  [ 9.60664749]
#  [10.31730964]
#  [ 8.65172533]
#  [ 9.33604563]
#  [10.26354262]
#  [ 9.60923715]
#  [ 9.04362656]
#  [ 9.09963883]
#  [ 8.85572202]
#  [ 8.53986189]
#  [ 9.62081615]
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import math

print('Mean absolute error:', mean_absolute_error(y_test, y_pred))

print("Mean squared error:", mean_squared_error(y_test, y_pred))
print('variance score:',r2_score(y_test, y_pred))

print('Root Mean Squared Error:',math.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Mean absolute error: 3.3535687557311786
# Mean squared error: 16.584980665046483
# variance score: 0.16772135793824272
# Root Mean Squared Error: 4.072466164997136
